// %% [markdown]
// # Code generators
//
// Source generators aim to enable compile time metaprogramming, that is, code that can be created at compile time and added to the compilation. Source generators will be able to read the contents of the compilation before running, as well as access any additional files, enabling generators to introspect both user C# code and generator specific files.
//
// * source generator is just a dll.
// * source generator hooks into compiler pipeline
// * Explicitly *additive* only
// * Run un-ordered
// * May access additional files, that is, non-C# source texts.
// * The two features added for code generators are extensions to partial method syntax, and module initializers.
//
// ![image.png](attachment:image.png)
//
// ## Demo
//
// https://sourcegen.dev/
//
// ## Usecases
//
// Might benefit from source generators:
//
// * ASP.NET: Improve startup time
// * Blazor and Razor: Massively reduce tooling burden
// * Azure Functions: regex compilation during startup
// * Azure SDK
// * gRPC
// * Resx file generation
// * System.CommandLine
// * Serializers
//
//
// ## Project highlight
//
// * [www.cazzulino.com/ThisAssembly/](https://www.cazzulino.com/ThisAssembly/)
// * [github.com/davidfowl/uController](https://github.com/davidfowl/uController)
// * [github.com/KathleenDollard/StarFruit2](https://github.com/KathleenDollard/StarFruit2)

// %% [markdown]
// ## Reference
//
// * https://github.com/dotnet/roslyn/blob/master/docs/features/source-generators.md
// * https://devblogs.microsoft.com/dotnet/introducing-c-source-generators/
// * https://devblogs.microsoft.com/dotnet/new-c-source-generator-samples/
// * https://github.com/dotnet/roslyn-sdk/tree/master/samples/CSharp/SourceGenerators
// * https://medium.com/rocket-mortgage-technology-blog/generating-code-in-c-1868ebbe52c5
// * https://www.youtube.com/watch?v=3YwwdoRg2F4&ab_channel=dotNET
// * https://www.youtube.com/watch?v=pqLs7X6Cr6s&ab_channel=NDCConferences
// * https://www.youtube.com/watch?v=A4479Etdx4I&ab_channel=.NETFoundation
// * https://docs.microsoft.com/en-us/dotnet/csharp/whats-new/csharp-9#support-for-code-generators
